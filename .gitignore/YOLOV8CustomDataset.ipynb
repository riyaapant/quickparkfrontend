# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
# Load a model
model = YOLO("yolov8n.yaml")
model = YOLO("yolov8n.pt")
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 65.5MB/s]

# %%
model.train(data="coco128.yaml", epochs=3)
# Out:
# Ultralytics YOLOv8.1.15 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
metrics = model.val()  # evaluate model performance on the validation set
results = model("/content/images/9.jpg")  # predict on an image
# Out:
# Ultralytics YOLOv8.1.15 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# val: Scanning /content/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100%|██████████| 128/128 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:38<00:00,  4.83s/it]
#                    all        128        929      0.676      0.536      0.623      0.466
#                 person        128        254      0.841      0.646      0.774      0.554
#                bicycle        128          6       0.62      0.333      0.322      0.266
#                    car        128         46      0.837      0.217      0.277      0.176
#             motorcycle        128          5      0.832       0.99      0.962       0.78
#               airplane        128          6      0.818      0.757      0.887      0.663
# ...

# %%
# !yolo task=detect mode=predict model="/content/yolov8n.pt" source="/content/images/6.jpg"
# Out:
# Ultralytics YOLOv8.1.15 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/images/6.jpg: 480x640 1 car, 1 motorcycle, 382.4ms
# Speed: 11.6ms preprocess, 382.4ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython import display
display.clear_output()
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.15 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.5/107.7 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display,Image

# %%
#Custom Training

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/YOLOV8
# Out:
# /content/drive/MyDrive/YOLOV8

# %%
# !ls
# Out:
# dataset  data.yaml  runs  YOLOV8CustomDataset.ipynb  yolov8n.pt

# %%
# !pip install pyyaml

# %%
import yaml

# Load YAML file
with open('/content/drive/MyDrive/YOLOV8/data.yaml', 'r') as file:
    data = yaml.safe_load(file)

# %%
# Access data
print(data['train'])
print(data['val'])
print(data['nc'])
print(data['names'])
# Out:
# /content/drive/MyDrive/YOLOV8/dataset/train/images
# /content/drive/MyDrive/YOLOV8/dataset/valid/images
# 1
# ['numberplate']

# %%
# !yolo task=detect mode=train model="/content/yolov8n.pt" data=data.yaml epochs=3  plots=True
# Out:
# Ultralytics YOLOv8.1.15 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !ls runs/detect/train5/
# Out:
# args.yaml					     labels.jpg    train_batch0.jpg
# confusion_matrix_normalized.png			     P_curve.png   train_batch1.jpg
# confusion_matrix.png				     PR_curve.png  train_batch2.jpg
# events.out.tfevents.1708237034.663ffe61585f.28370.0  R_curve.png   val_batch0_labels.jpg
# F1_curve.png					     results.csv   val_batch0_pred.jpg
# labels_correlogram.jpg				     results.png   weights

# %%
Image(filename='runs/detect/train5/confusion_matrix.png' ,width=600)

# %%
Image(filename='runs/detect/train5/results.png')

# %%
#Validate Custom Model

# !yolo task=detect mode=val model=runs/detect/train5/weights/best.pt data=data.yaml
# Out:
# Ultralytics YOLOv8.1.15 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/YOLOV8/dataset/valid/labels.cache... 6 images, 0 backgrounds, 0 corrupt: 100% 6/6 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:02<00:00,  2.37s/it]
#                    all          6          6    0.00278      0.833     0.0209     0.0125
# Speed: 18.6ms preprocess, 342.7ms inference, 0.0ms loss, 5.7ms postprocess per image
# Results saved to runs/detect/val4
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
#Inference with custom data

# !yolo task=detect mode=predict model=runs/detect/train5/weights/best.pt conf=0.25 source=dataset/test/images
# Out:
# Ultralytics YOLOv8.1.15 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/6 /content/drive/MyDrive/YOLOV8/dataset/test/images/10.jpg: 448x640 (no detections), 206.3ms
# image 2/6 /content/drive/MyDrive/YOLOV8/dataset/test/images/11.jpg: 480x640 (no detections), 184.7ms
# image 3/6 /content/drive/MyDrive/YOLOV8/dataset/test/images/6.jpg: 480x640 (no detections), 160.8ms
# image 4/6 /content/drive/MyDrive/YOLOV8/dataset/test/images/7.jpg: 384x640 (no detections), 131.3ms
# image 5/6 /content/drive/MyDrive/YOLOV8/dataset/test/images/8.jpg: 448x640 (no detections), 141.6ms
# image 6/6 /content/drive/MyDrive/YOLOV8/dataset/test/images/9.jpg: 448x640 (no detections), 146.1ms
# Speed: 3.6ms preprocess, 161.8ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict6
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import glob
from IPython.display import Image,display
for image_path in glob.glob('runs/detect/predict6/*.jpg')[:3]:
  display(Image(filename=image_path, width=600))
  print("\n")
